# %%
from sqlalchemy import create_engine, text

# %%
import pandas as pd

# %%
database_name = 'scooters'

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
connection_string
# Out:
# 'postgresql://postgres:postgres@localhost:5432/scooters'

# %%
engine = create_engine(connection_string)

# %%
query = '''
SELECT *
FROM scooters
LIMIT 100;
'''

with engine.connect() as connection:
    result = connection.execute(text(query))

# %%
with engine.connect() as connection:
    scooters_table = pd.read_sql(text(query), con = connection)

scooters_table.head(10)
# Out:
#               pubdatetime   latitude  longitude        sumdid sumdtype  \
# 0 2019-05-01 00:01:41.247  36.136822 -86.799877  PoweredLIRL1  Powered
# 1 2019-05-01 00:01:41.247  36.191252 -86.772945  PoweredXWRWC  Powered
# 2 2019-05-01 00:01:41.247  36.144752 -86.806293  PoweredMEJEH  Powered
# 3 2019-05-01 00:01:41.247  36.162056 -86.774688  Powered1A7TC  Powered
# 4 2019-05-01 00:01:41.247  36.150973 -86.783109  Powered2TYEF  Powered
# 5 2019-05-01 00:01:41.247  36.157188 -86.769978  Powered3F3VK  Powered
# 6 2019-05-01 00:01:41.247  36.154348 -86.784765  PoweredVL7YG  Powered
# 7 2019-05-01 00:01:41.247  36.158930 -86.775987  Powered5LNUG  Powered
# 8 2019-05-01 00:01:41.247  36.135993 -86.804226  Powered7SPQQ  Powered
# 9 2019-05-01 00:01:41.247  36.148938 -86.811256  PoweredBV1DT  Powered
#
#    chargelevel sumdgroup  costpermin companyname
# 0         93.0   scooter         0.0        Bird
# 1         35.0   scooter         0.0        Bird
# ...

# %%
query2 = '''
SELECT *
FROM trips
LIMIT 100;
'''

with engine.connect() as connection:
    result = connection.execute(text(query2))

# %%
with engine.connect() as connection:
    trips_table = pd.read_sql(text(query2), con = connection)

trips_table.head()
# Out:
#              pubtimestamp companyname triprecordnum         sumdid  \
# 0 2019-05-01 00:00:55.423        Bird       BRD2134   Powered9EAJL
# 1 2019-05-01 00:03:33.147        Lyft          LFT5  Powered296631
# 2 2019-05-01 00:05:55.570        Bird       BRD2168   Powered7S2UU
# 3 2019-05-01 00:05:55.570        Bird       BRD2166   PoweredZIIVX
# 4 2019-05-01 00:05:55.570        Bird       BRD2165   PoweredJ7MB3
#
#    tripduration  tripdistance   startdate        starttime     enddate  \
# 0        3.0000     958.00528  2019-05-01  00:00:20.460000  2019-05-01
# 1        1.7156    1371.39112  2019-05-01  00:01:50.090000  2019-05-01
# 2        3.0000    2296.58800  2019-05-01  00:03:47.363333  2019-05-01
# 3        3.0000    1200.78744  2019-05-01  00:04:21.386666  2019-05-01
# 4        2.0000     351.04988  2019-05-01  00:04:27.796666  2019-05-01
#
#            endtime  startlatitude  startlongitude  endlatitude  endlongitude  \
# ...

# %%
query3 = '''
select count(*) as total_number_of_null
from scooters
where chargelevel IS NULL 
'''

with engine.connect() as connection:
    result = connection.execute(text(query3))
    
with engine.connect() as connection:
    nulls_within_chargelevel = pd.read_sql(text(query3), con = connection)

nulls_within_chargelevel
# Out:
#    total_number_of_null
# 0                   770

# %%
query4 = '''
select 
	min(pubdatetime) as first_date,
	max(pubdatetime) as last_date
from scooters
'''

with engine.connect() as connection:
    result = connection.execute(text(query4))
    
with engine.connect() as connection:
    daterange_for_pubdatetime = pd.read_sql(text(query4), con = connection)

daterange_for_pubdatetime
# Out:
#                first_date           last_date
# 0 2019-05-01 00:01:41.247 2019-07-31 23:59:57

# %%
scooters_table['pubdatetime'] = pd.to_datetime(scooters_table['pubdatetime'])

# %%
scooters_table.head()
# Out:
#               pubdatetime   latitude  longitude        sumdid sumdtype  \
# 0 2019-05-01 00:01:41.247  36.136822 -86.799877  PoweredLIRL1  Powered
# 1 2019-05-01 00:01:41.247  36.191252 -86.772945  PoweredXWRWC  Powered
# 2 2019-05-01 00:01:41.247  36.144752 -86.806293  PoweredMEJEH  Powered
# 3 2019-05-01 00:01:41.247  36.162056 -86.774688  Powered1A7TC  Powered
# 4 2019-05-01 00:01:41.247  36.150973 -86.783109  Powered2TYEF  Powered
#
#    chargelevel sumdgroup  costpermin companyname
# 0         93.0   scooter         0.0        Bird
# 1         35.0   scooter         0.0        Bird
# 2         90.0   scooter         0.0        Bird
# 3         88.0   scooter         0.0        Bird
# 4         98.0   scooter         0.0        Bird

# %%
trips_table['pubtimestamp'] = pd.to_datetime(trips_table['pubtimestamp'])

# %%
trips_table.head()
# Out:
#              pubtimestamp companyname triprecordnum         sumdid  \
# 0 2019-05-01 00:00:55.423        Bird       BRD2134   Powered9EAJL
# 1 2019-05-01 00:03:33.147        Lyft          LFT5  Powered296631
# 2 2019-05-01 00:05:55.570        Bird       BRD2168   Powered7S2UU
# 3 2019-05-01 00:05:55.570        Bird       BRD2166   PoweredZIIVX
# 4 2019-05-01 00:05:55.570        Bird       BRD2165   PoweredJ7MB3
#
#    tripduration  tripdistance   startdate        starttime     enddate  \
# 0        3.0000     958.00528  2019-05-01  00:00:20.460000  2019-05-01
# 1        1.7156    1371.39112  2019-05-01  00:01:50.090000  2019-05-01
# 2        3.0000    2296.58800  2019-05-01  00:03:47.363333  2019-05-01
# 3        3.0000    1200.78744  2019-05-01  00:04:21.386666  2019-05-01
# 4        2.0000     351.04988  2019-05-01  00:04:27.796666  2019-05-01
#
#            endtime  startlatitude  startlongitude  endlatitude  endlongitude  \
# ...

# %%
(trips_table
 .assign(month = trips_table['pubtimestamp'].dt.month_name())
 .month
 .value_counts(sort = False)
)
# Out:
# month
# May    100
# Name: count, dtype: int64

# %%
(scooters_table
 .assign(month = scooters_table['pubdatetime'].dt.month_name())
 .month
 .value_counts(sort = False)
)
# Out:
# month
# May    100
# Name: count, dtype: int64

# %%
trips_grouped = (trips_table
                     .assign(weekday = trips_table['pubtimestamp'].dt.day_name())
                      .query('weekday != "Saturday" and weekday != "Sunday"')   # remove the weekends
                     .groupby(pd.Grouper(key = 'pubtimestamp',
                                         freq = '1h',
                                         origin = 'epoch'
                                        ))
 ['startdate']
 .count()
 .reset_index()       
)

# %%
trips_grouped
# Out:
#            pubtimestamp  startdate
# 0   2019-05-01 00:00:00         92
# 1   2019-05-01 01:00:00          2
# 2   2019-05-01 02:00:00          4
# 3   2019-05-01 03:00:00          0
# 4   2019-05-01 04:00:00          0
# ..                  ...        ...
# 120 2019-05-06 00:00:00          0
# 121 2019-05-06 01:00:00          0
# 122 2019-05-06 02:00:00          0
# 123 2019-05-06 03:00:00          0
# 124 2019-05-06 04:00:00          1
#
# [125 rows x 2 columns]

# %%
triptab = '''
SELECT pubtimestamp, companyname, sumdid, startdate, starttime, enddate, endtime, startlatitude, startlongitude, endlatitude, endlongitude
FROM trips
WHERE tripduration BETWEEN 1 AND 1440;
'''
with engine.connect() as connection:
    trips = pd.read_sql(text(triptab), con = connection)
trips.head()
trips.to_csv('tripsdata.csv', index=False)

# %%
trips.head()
# Out:
#              pubtimestamp companyname         sumdid   startdate  \
# 0 2019-05-01 00:00:55.423        Bird   Powered9EAJL  2019-05-01
# 1 2019-05-01 00:03:33.147        Lyft  Powered296631  2019-05-01
# 2 2019-05-01 00:05:55.570        Bird   Powered7S2UU  2019-05-01
# 3 2019-05-01 00:05:55.570        Bird   PoweredZIIVX  2019-05-01
# 4 2019-05-01 00:05:55.570        Bird   PoweredJ7MB3  2019-05-01
#
#          starttime     enddate          endtime  startlatitude  \
# 0  00:00:20.460000  2019-05-01  00:02:52.346666       36.15710
# 1  00:01:50.090000  2019-05-01  00:03:33.026666       36.15797
# 2  00:03:47.363333  2019-05-01  00:07:13.596666       36.15470
# 3  00:04:21.386666  2019-05-01  00:06:59.176666       36.14940
# 4  00:04:27.796666  2019-05-01  00:06:23.150000       36.17780
#
#    startlongitude  endlatitude  endlongitude
# 0       -86.80360     36.15660     -86.80670
# 1       -86.77896     36.16054     -86.77689
# 2       -86.78180     36.15650     -86.78680
# ...

# %%
company_names = '''
select companyname as companyname_scooters
from scooters
group by companyname
'''

with engine.connect() as connection:
    result = connection.execute(text(company_names))
    
with engine.connect() as connection:
    company_names = pd.read_sql(text(company_names), con = connection)

company_names   # this query gives us the company names present in the dataset
# Out:
#   companyname_scooters
# 0                 Bird
# 1                 Bolt
# 2               Gotcha
# 3                 Jump
# 4                 Lime
# 5                 Lyft
# 6                 Spin

# %%
number_of_scooters_per_company = '''
SELECT
	companyname, 
	COUNT(distinct sumdid) as number_of_scooters_per_company
FROM scooters
WHERE sumdgroup ilike 'scooter'
GROUP BY companyname
'''

with engine.connect() as connection:
    result = connection.execute(text(number_of_scooters_per_company))
    
with engine.connect() as connection:
    number_of_scooters_per_company = pd.read_sql(text(number_of_scooters_per_company), con = connection)

number_of_scooters_per_company
# Out:
#   companyname  number_of_scooters_per_company
# 0        Bird                            3860
# 1        Bolt                             360
# 2      Gotcha                             224
# 3        Jump                            1210
# 4        Lime                            1818
# 5        Lyft                            1735
# 6        Spin                             805

# %%
# total_scooters = pd.read_csv(r'../DA11/Python/projects/scooters-hawaiian/Corrected_total_scooters.csv')

total_scooters = pd.read_csv('C:/Users/Barbie/Desktop/DA11/Python/projects/scooters-hawaiian/Corrected_total_scooters.csv',
                          on_bad_lines='skip')
#                           nrows = 4495)

# %%
total_scooters
# Out:
#   company_name  total_scooter_trips_for_may  total_scooter_trips_for_june  \
# 0         Bird                         3064                          3646
# 1         Bolt                          346                           355
# 2       Gotcha                          223                           223
# 3         Jump                          976                          1037
# 4         Lime                         1631                          1762
# 5         Lyft                         1376                          1516
# 6         Spin                          687                           770
#
#    total_scooter_trips_for_july  total_usage
# 0                          3860        10570
# 1                           360         1061
# 2                           224          670
# 3                          1210         3223
# 4                          1818         5211
# 5                          1735         4627
# 6                           805         2262

# %%
plt.bar(
